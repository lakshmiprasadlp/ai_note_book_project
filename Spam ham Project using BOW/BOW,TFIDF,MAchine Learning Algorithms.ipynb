# %% [markdown]
# # Spam ham Project using BOW

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#massage=pd.read_csv("/content/drive/MyDrive/04 notbook projecr/spam.csv", encoding='latin-1',names=["v1","v2"])

# %%
import pandas as pd
message=pd.read_csv("/content/drive/MyDrive/04 notbook projecr/spam.csv", encoding='latin-1')

# %%
import pandas as pd
import nltk
nltk.download('stopwords')
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

# Load the dataset
message = pd.read_csv("/content/drive/MyDrive/04 notbook projecr/spam.csv", encoding='latin-1')

# Initialize the stemmer and stop words list
stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))

# Clean the data
message['v2'] = message['v2'].apply(lambda x: ' '.join([stemmer.stem(word) for word in x.split() if word not in stop_words]))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
message.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  go jurong point, crazy.. avail bugi n great wo...        NaN
# 1   ham                        ok lar... joke wif u oni...        NaN
# 2  spam  free entri 2 wkli comp win fa cup final tkt 21...        NaN
# 3   ham          u dun say earli hor... u c alreadi say...        NaN
# 4   ham            nah i think goe usf, live around though        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
# Separate the data into features and target
x = message['v2']
y = message['v1']

# Convert the target variable to numeric values
y = y.replace(['ham', 'spam'], [0, 1])

# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# Create a Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
x_train = cv.fit_transform(x_train)
x_test = cv.transform(x_test)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

# Train the Multinomial Naive Bayes model
clf = MultinomialNB()
clf.fit(x_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

# Print the results
print("Accuracy:", accuracy)
print("\nClassification Report:")
print(report)
# Out:
# Accuracy: 0.989237668161435
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       949
#            1       0.99      0.94      0.96       166
#
#     accuracy                           0.99      1115
#    macro avg       0.99      0.97      0.98      1115
# weighted avg       0.99      0.99      0.99      1115

# %%
def predict_spam(text):
  # Clean the text
  text = ' '.join([stemmer.stem(word) for word in text.split() if word not in stop_words])

  # Convert the text to a vector
  x_test = cv.transform([text])

  # Make a prediction
  prediction = clf.predict(x_test)[0]

  # Return the prediction
  if prediction == 0:
    return "ham"
  else:
    return "spam"

# Example usage
text = "This is a promotional email. Please ignore."
prediction = predict_spam(text)
print(prediction)
# Out:
# ham

# %%
text = input("Enter a text: ")
prediction = predict_spam(text)
print(prediction)
# Out:
# Enter a text: Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005
# spam

# %%
#Even my brother is not like to speak with me. They treat me like aids patent.,,,

# %%
text = input("Enter a text: ")
prediction = predict_spam(text)
print(prediction)
# Out:
# Enter a text: Even my brother is not like to speak with me. They treat me like aids patent.,,,
# ham

# %%
#FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, �1.50 to rcv"

# %%
text = input("Enter a text: ")
prediction = predict_spam(text)
print(prediction)
# Out:
# Enter a text: #FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, �1.50 to rcv"
# spam
